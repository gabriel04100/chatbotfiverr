# %% [markdown]
# ## Scrapper testing

# %%
URL='https://lgu.edu.pk/'
from scrapper import Scrapper
my_scrapper=Scrapper(URL)

# %%
my_scrapper.scrape()
main_page = my_scrapper.soup

# %%
print(main_page.body.text)
# Out:
#  Skip to content
#
#
#
#
#
#
#
#
#
# NOCTendersEventsPoliciesResultsLatestConferencesNotificationsRozee PortalDate Sheet4th ICCSATNewAcademic CalendarAdmission List
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search for:
#
#
#
#
#
#
#
#
# ...
